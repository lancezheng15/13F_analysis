# %% [markdown]
# # Setup and Configuration
#
# This notebook provides environment setup, configuration settings, and utility functions for the 13F analysis notebooks.
#
# ## Table of Contents
# 1. [Environment Setup](#setup)
# 2. [Configuration Settings](#config)
# 3. [Utility Functions](#utilities)
# 4. [Data Loading Functions](#data-loading)
# 5. [Visualization Settings](#viz-settings)
# 6. [Export Functions](#export)
